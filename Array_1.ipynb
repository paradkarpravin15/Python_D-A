# %% [markdown]
# # **Numpy Array Dimensions**
# 1D Array
# 2D Array
# 3D Array

# %%
import numpy as np

# %%
a = np.array(5)     #scalar array
a
np.ndim(a)
# Out:
# 0

# %%
one = np.array([1,2,3,4,5])
one
np.ndim(one)
# Out:
# 1
